# %%
import numpy as np
import matplotlib.pyplot as plt

# Defining the Fuction F(x) which is given in the question as f(x) = x^2 + log x
def f(x):
    return pow(x,2) + np.log(x);




# Calculate the Linear Taylor polynomial
# So, for the function f(x) = x^2 + log x, the linear Taylor polynomial about x = 1 is:
# Linear(x) = f(1) + f'(1)(x - 1)
#           = 1^2 + log(1) + (2 * 1 + (1/1))(x - 1)
#           = 1 + 0 + (2 + 1)(x - 1)
#           = 3x - 2

def L(x):
    # x^2 + log x + (2a - 1)(x - a)
    return (3*x)-2;




# Calculate the Quadratic Taylor polynomial
# Quadratic(x) = f(1) + f'(1)(x - 1) + (f''(1)/2!) (x - 1)^2
#           = 1^2 + log(1) + (2 * 1 + (1/1))(x - 1) + ((2 - (1/1^2))/2)(x - 1)^2
#           = 1 + 0 + (2 + 1)(x - 1) + ((2 - 1)/2)(x - 1)^2
#           = 3x - 2 + (x - 1)^2/2
def Q(x):
    return (3*x)-2 + 0.5*pow((x-1),2);





# Setting the Value of x as given in the Question
x = np.linspace(0, 2, 500)

# Plotting the first graph i.e. (a)
plt.plot(x, f(x), 'r', label='f(x) = x^2 + log(x)')
plt.plot(x, L(x), 'g', label='L(x) = 3x - 2')
plt.plot(x, Q(x), 'b', label='Q(x) = 3x - 2 + (x - 1)^2/2')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of f(x), L(x), and Q(x)')
plt.grid()
plt.show()


# Calculate the Function eQ(x)
def eQ(x):
    return f(x) - Q(x);

# Calculate the Function eL(x)
def eL(x):
    return f(x) - L(x);

# Plotting the Second graph i.e. (b)
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, eL(x)/(x-1), label='eL(x)/(x-1)')
plt.plot(x, eQ(x)/pow((x-1),2), label='eQ(x)/(x-1)^2')
# plt.plot(x, f(x), 'r', label='f(x) = x^2 + log(x)')
plt.legend()
plt.title(" Graphs of Errors ")
plt.show()
# Out:
# /var/folders/_x/pxd536m94pbgktwj7nsh9xx40000gn/T/ipykernel_45549/2394194372.py:6: RuntimeWarning: divide by zero encountered in log
#   return pow(x,2) + np.log(x);
